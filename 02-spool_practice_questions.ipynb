# %% [markdown]
# # Practice Problems with Spools
#
# Let's practice some of the skills we've just seen for working with spools.
#
# If you get stuck, please talk to any of the workshop facilitators, or check out spool_answer.ipynb for hints and completed solutions.

# %% [markdown]
# ## Environment Setup
# Run the cells below for your setup.

# %%
# %%capture

# First ensure DASCore is installed. If not, install and restart the kernel.
try:
    import dascore as dc
except ImportError:
    # !pip install dascore
    # !pip install ipympl
    # resetart kernel
    import IPython
    IPython.Application.instance().kernel.do_shutdown(True) #automatically restarts kernel


import numpy as np
from rich import print

# %%
import numpy as np

import dascore as dc
from dascore.utils.time import to_timedelta64

# %%
dc.__version__
# Out:
# '0.1.6'

# %% [markdown]
# ## Practice: Create a spool
#
# Create a spool that only contains the file "Spool_example_data/patch3.h5".
#
# You'll need to change the das_folder_path to the path for your data (either locally or on Google Drive). If you're pulling data from Google Drive, you'll need to make a shortcut to the directory you're referring to.
# If your shortcut of "Example_data" is in "MyDrive", the cell below shows the path to the folder "Spool_example_data".

# %%
das_folder_path = "/Users/fkutschera/Documents/PhD/conferences/2025_SSA/DAS/HtoM_Spool_example_data"

# %%
#Answer here
spool = dc.spool(das_folder_path)

# %%
print(spool)
# Out:
# DASCore DirectorySpool 🧵 (3 Patches)
#     Path: /Users/fkutschera/Documents/PhD/conferences/2025_SSA/DAS/HtoM_Spool_example_data

# %%
contents = spool.get_contents()

display(contents)
# Out:
#   network           dims tag                   time_min  \
# 0          time,distance     2022-04-21 05:56:34.998177
# 1          time,distance     2022-04-21 05:56:36.998177
# 2          time,distance     2022-04-21 05:56:37.998177
#
#                     time_max    data_type data_category instrument_id  \
# 0 2022-04-21 05:56:36.997927  strain_rate                    01CE1469
# 1 2022-04-21 05:56:37.997927  strain_rate                    01CE1469
# 2 2022-04-21 05:56:38.997927  strain_rate                    01CE1469
#
#         path file_format              time_step file_version station  \
# 0  patch3.h5      DASDAE 0 days 00:00:00.000250            1
# 1  patch2.h5      DASDAE 0 days 00:00:00.000250            1
# 2  patch1.h5      DASDAE 0 days 00:00:00.000250            1
#
#   experiment_id  _modified
# 0                    False
# 1                    False
# 2                    False

# %%
patch = spool[0]
#spool = dc.spool([patch])

# %%
print(patch)
# Out:
# DASCore Patch ⚡
# ---------------
# ➤ Coordinates (time: 8000, distance: 956)
#     *time: CoordRange( min: 2022-04-21T05:56:34.998177 max: 2022-04-21T05:56:36.997927 step: 0.00025s shape:
# (8000,) dtype: datetime64[ns] units: s )
#     *distance: CoordRange( min: 95 max: 1050 step: 1 shape: (956,) dtype: int64 )
# ➤ Data (float64)
#    [[-2.402 -2.83  -0.892 ... -0.735 -0.807 -0.243]
#     [-2.297 -2.64  -0.709 ... -0.804 -0.84  -0.35 ]
#     [-2.11  -2.361 -0.516 ... -0.858 -0.864 -0.462]
#     ...
#     [-5.094 -5.502 -0.492 ...  0.096  0.266  0.29 ]
#     [-5.161 -5.157 -0.155 ...  0.02   0.198  0.194]
#     [-5.092 -4.662  0.171 ... -0.051  0.133  0.102]]
# ➤ Attributes
#     data_type: strain_rate
#     instrument_id: 01CE1469
#     history: ("update_coords(distance='CoordRange( min: 0 max: 2431 step: 1 shape: (2432,) dtype: int64 )')",
# "taper(time='0.075',window_type='hann')", "pass_filter(corners='4',time='(10,150)',zerophase='True')")

# %% [markdown]
# ## Practice: Chunk a spool
#
# Chunk the spool to have 0.5 second patches with 0.25 second overlaps. How can you visualize the results or print information about the results to know whether this was successful?

# %%
spool = dc.spool([patch])

# %%
#Answer here
subspool=spool.chunk(time=0.5, overlap=0.25)
print(subspool)
# Out:
# DASCore MemorySpool 🧵 (7 Patches)
#     Time Span: <1.5s> 2022-04-21T05:56:34.998177 to 2022-04-21T05:56:36.498177

# %%
for i in range(7):
    subspool[i].viz.waterfall(show=True,scale=(-2,2))

# %% [markdown]
# ## Practice: Map method
#
# Use the map method to apply a patch taper method to all patches in the spool using "hamming" window type. Try to visualize the results as you change the taper parameter.

# %%
len(subspool)
# Out:
# 7

# %%
#Answer here
def taper(patch, window_type, time):
    return patch.taper(window_type=window_type, time=time)

# %%
subspool_tapered = subspool.map(taper, window_type="hamming", time=0.5, progress=True)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
subspool_tapered
# Out:
# [DASCore Patch ⚡
#  ---------------
#  ➤ Coordinates (time: 2000, distance: 956)
#      *time: CoordRange( min: 2022-04-21T05:56:34.998177 max: 2022-04-21T05:56:35.497927 step: 0.00025s shape: (2000,) dtype: datetime64[ns] units: s )
#      *distance: CoordRange( min: 95 max: 1050 step: 1 shape: (956,) dtype: int64 )
#  ➤ Data (float64)
#     [[-0.192 -0.226 -0.071 ... -0.059 -0.065 -0.019]
#      [-0.184 -0.211 -0.057 ... -0.064 -0.067 -0.028]
#      [-0.169 -0.189 -0.041 ... -0.069 -0.069 -0.037]
#      ...
#      [ 0.168  0.178 -0.078 ... -0.011  0.048  0.028]
#      [ 0.135  0.156 -0.082 ... -0.026  0.03   0.016]
#      [ 0.096  0.127 -0.084 ... -0.042  0.011  0.003]]
#  ➤ Attributes
#      data_type: strain_rate
#      instrument_id: 01CE1469
#      history: ("update_coords(distance='CoordRange( min: 0 max: 2431 step: 1 shape: (2432,) dtype: int64 )')", "taper(time='0.075',window_type='hann')", "pass_filter(corners='4',time='(10,150)',zerophase='True')", "taper(time='0.5',window_type='hamming')"),
#  DASCore Patch ⚡
#  ---------------
#  ➤ Coordinates (time: 2000, distance: 956)
#      *time: CoordRange( min: 2022-04-21T05:56:35.248177 max: 2022-04-21T05:56:35.747927 step: 0.00025s shape: (2000,) dtype: datetime64[ns] units: s )
#      *distance: CoordRange( min: 95 max: 1050 step: 1 shape: (956,) dtype: int64 )
#  ➤ Data (float64)
#     [[-0.165 -0.173 -0.068 ... -0.172 -0.176 -0.176]
#      [-0.166 -0.164 -0.075 ... -0.171 -0.177 -0.173]
#      [-0.163 -0.15  -0.079 ... -0.171 -0.179 -0.171]
#      ...
#      [-0.023 -0.018 -0.093 ... -0.077 -0.049 -0.025]
#      [-0.011 -0.005 -0.078 ... -0.067 -0.041 -0.02 ]
#      [ 0.003  0.009 -0.062 ... -0.056 -0.032 -0.016]]
#  ➤ Attributes
#      data_type: strain_rate
#      instrument_id: 01CE1469
#      history: ("update_coords(distance='CoordRange( min: 0 max: 2431 step: 1 shape: (2432,) dtype: int64 )')", "taper(time='0.075',window_type='hann')", "pass_filter(corners='4',time='(10,150)',zerophase='True')", "taper(time='0.5',window_type='hamming')"),
#  DASCore Patch ⚡
#  ---------------
#  ➤ Coordinates (time: 2000, distance: 956)
#      *time: CoordRange( min: 2022-04-21T05:56:35.498177 max: 2022-04-21T05:56:35.997927 step: 0.00025s shape: (2000,) dtype: datetime64[ns] units: s )
#      *distance: CoordRange( min: 95 max: 1050 step: 1 shape: (956,) dtype: int64 )
#  ➤ Data (float64)
#     [[ 0.053  0.095 -0.083 ... -0.058 -0.009 -0.01 ]
#      [ 0.008  0.059 -0.081 ... -0.073 -0.029 -0.023]
#      [-0.037  0.024 -0.075 ... -0.088 -0.049 -0.036]
#      ...
#      [-0.081 -0.101 -0.048 ... -0.089 -0.085 -0.082]
#      [-0.063 -0.073 -0.056 ... -0.088 -0.085 -0.083]
#      [-0.039 -0.039 -0.061 ... -0.086 -0.084 -0.082]]
#  ➤ Attributes
#      data_type: strain_rate
#      instrument_id: 01CE1469
#      history: ("update_coords(distance='CoordRange( min: 0 max: 2431 step: 1 shape: (2432,) dtype: int64 )')", "taper(time='0.075',window_type='hann')", "pass_filter(corners='4',time='(10,150)',zerophase='True')", "taper(time='0.5',window_type='hamming')"),
#  DASCore Patch ⚡
#  ---------------
#  ➤ Coordinates (time: 2000, distance: 956)
#      *time: CoordRange( min: 2022-04-21T05:56:35.748177 max: 2022-04-21T05:56:36.247927 step: 0.00025s shape: (2000,) dtype: datetime64[ns] units: s )
#      *distance: CoordRange( min: 95 max: 1050 step: 1 shape: (956,) dtype: int64 )
#  ➤ Data (float64)
#     [[ 0.02   0.025 -0.045 ... -0.045 -0.025 -0.014]
#      [ 0.038  0.042 -0.026 ... -0.035 -0.019 -0.014]
#      [ 0.058  0.06  -0.008 ... -0.026 -0.015 -0.015]
#      ...
#      [ 0.011  0.035 -0.122 ... -0.114 -0.113 -0.124]
#      [-0.     0.007 -0.102 ... -0.111 -0.112 -0.122]
#      [-0.01  -0.021 -0.082 ... -0.106 -0.11  -0.119]]
#  ➤ Attributes
#      data_type: strain_rate
#      instrument_id: 01CE1469
#      history: ("update_coords(distance='CoordRange( min: 0 max: 2431 step: 1 shape: (2432,) dtype: int64 )')", "taper(time='0.075',window_type='hann')", "pass_filter(corners='4',time='(10,150)',zerophase='True')", "taper(time='0.5',window_type='hamming')"),
#  DASCore Patch ⚡
#  ---------------
#  ➤ Coordinates (time: 2000, distance: 956)
#      *time: CoordRange( min: 2022-04-21T05:56:35.998177 max: 2022-04-21T05:56:36.497927 step: 0.00025s shape: (2000,) dtype: datetime64[ns] units: s )
#      *distance: CoordRange( min: 95 max: 1050 step: 1 shape: (956,) dtype: int64 )
#  ➤ Data (float64)
#     [[-0.011 -0.    -0.063 ... -0.084 -0.081 -0.081]
#      [ 0.019  0.041 -0.061 ... -0.081 -0.077 -0.078]
#      [ 0.049  0.083 -0.055 ... -0.077 -0.073 -0.075]
#      ...
#      [-0.026 -0.028 -0.104 ...  0.033  0.025  0.064]
#      [-0.043 -0.05  -0.088 ...  0.028  0.025  0.063]
#      [-0.062 -0.076 -0.068 ...  0.023  0.025  0.062]]
#  ➤ Attributes
#      data_type: strain_rate
#      instrument_id: 01CE1469
#      history: ("update_coords(distance='CoordRange( min: 0 max: 2431 step: 1 shape: (2432,) dtype: int64 )')", "taper(time='0.075',window_type='hann')", "pass_filter(corners='4',time='(10,150)',zerophase='True')", "taper(time='0.5',window_type='hamming')"),
#  DASCore Patch ⚡
#  ---------------
#  ➤ Coordinates (time: 2000, distance: 956)
#      *time: CoordRange( min: 2022-04-21T05:56:36.248177 max: 2022-04-21T05:56:36.747927 step: 0.00025s shape: (2000,) dtype: datetime64[ns] units: s )
#      *distance: CoordRange( min: 95 max: 1050 step: 1 shape: (956,) dtype: int64 )
#  ➤ Data (float64)
#     [[-0.017 -0.046 -0.062 ... -0.1   -0.108 -0.116]
#      [-0.02  -0.066 -0.043 ... -0.094 -0.104 -0.112]
#      [-0.018 -0.081 -0.025 ... -0.087 -0.1   -0.108]
#      ...
#      [ 0.064  0.21   0.017 ...  0.084  0.07   0.053]
#      [ 0.086  0.224  0.007 ...  0.084  0.071  0.052]
#      [ 0.106  0.234 -0.003 ...  0.08   0.071  0.049]]
#  ➤ Attributes
#      data_type: strain_rate
#      instrument_id: 01CE1469
#      history: ("update_coords(distance='CoordRange( min: 0 max: 2431 step: 1 shape: (2432,) dtype: int64 )')", "taper(time='0.075',window_type='hann')", "pass_filter(corners='4',time='(10,150)',zerophase='True')", "taper(time='0.5',window_type='hamming')"),
#  DASCore Patch ⚡
#  ---------------
#  ➤ Coordinates (time: 2000, distance: 956)
#      *time: CoordRange( min: 2022-04-21T05:56:36.498177 max: 2022-04-21T05:56:36.997927 step: 0.00025s shape: (2000,) dtype: datetime64[ns] units: s )
#      *distance: CoordRange( min: 95 max: 1050 step: 1 shape: (956,) dtype: int64 )
#  ➤ Data (float64)
#     [[-0.081 -0.103 -0.047 ...  0.019  0.025  0.061]
#      [-0.1   -0.131 -0.026 ...  0.015  0.025  0.059]
#      [-0.117 -0.158 -0.006 ...  0.013  0.026  0.057]
#      ...
#      [-0.408 -0.44  -0.039 ...  0.008  0.021  0.023]
#      [-0.413 -0.413 -0.012 ...  0.002  0.016  0.016]
#      [-0.407 -0.373  0.014 ... -0.004  0.011  0.008]]
#  ➤ Attributes
#      data_type: strain_rate
#      instrument_id: 01CE1469
#      history: ("update_coords(distance='CoordRange( min: 0 max: 2431 step: 1 shape: (2432,) dtype: int64 )')", "taper(time='0.075',window_type='hann')", "pass_filter(corners='4',time='(10,150)',zerophase='True')", "taper(time='0.5',window_type='hamming')")]

# %%
for i in range(7):
    subspool_tapered[i].viz.waterfall(show=True,scale=(-2,2))

# %% [markdown]
# ## Practice: Select method
#
# The cell below will create a new spool. Create a sub-spool of the new spool by selecting all patches with a station code that ends with an 's'.

# %%
in_memory_spool = dc.get_example_spool("diverse_das")

das_folder_path = dc.examples.spool_to_directory(in_memory_spool)
spool = dc.spool(das_folder_path)

# %%
contents = spool.get_contents()

display(contents)

# %%
#Answer here
