# %% [markdown]
# ## Introduction and Environment Setup

# %%
# %%capture

# First ensure DASCore is installed. If not, install and restart the kernel.
try:
    import dascore as dc
except ImportError:
    # !pip install dascore
    # !pip install ipympl
    # resetart kernel
    import IPython
    IPython.Application.instance().kernel.do_shutdown(True) #automatically restarts kernel


import numpy as np
from rich import print

# %%
import numpy as np

import dascore as dc
from dascore.utils.time import to_timedelta64

# %%
dc.__version__
# Out:
# '0.1.6'

# %%
# not needed locally
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# ## 3 ways to create a spool
# We can use dc.spool() to make a spool from:
#   * A single file
#   * A list of patches
#   * A directory of files
#
# The cell below should prepare the path to our data and data folder.
# You'll need to change the das_folder_path to the path for your data (either locally or on Google Drive). If you're pulling data from Google Drive, you'll need to make a shortcut to the directory you're referring to.
# If your shortcut of "Example_data" is in "MyDrive", then you can use the cell below directly.

# %%
#das_folder_path = "drive/MyDrive/Example_data/AtoG_Spool_example_data"
#das_file_path = "drive/MyDrive/Example_data/AtoG_Spool_example_data/patch1.h5"
das_folder_path = "/Users/fkutschera/Documents/PhD/conferences/2025_SSA/DAS/HtoM_Spool_example_data"
das_file_path = "/Users/fkutschera/Documents/PhD/conferences/2025_SSA/DAS/HtoM_Spool_example_data/patch1.h5"

# %% [markdown]
# From a single file

# %%
spool = dc.spool(das_file_path)
patch = spool[0]

# %% [markdown]
# From a list of patches

# %%
spool = dc.spool([patch])

# %% [markdown]
# From a directory of files

# %%
spool = dc.spool(das_folder_path)

# %% [markdown]
# What is contained in this spool?

# %%
spool
# Out:
# DASCore DirectorySpool 🧵 (3 Patches)
#     Path: /Users/fkutschera/Documents/PhD/conferences/2025_SSA/DAS/HtoM_Spool_example_data

# %% [markdown]
# This spool contains 3 patches (3 data files from the folder path)
# You can use "spool.get_contents()" to display the metadata.

# %%
contents = spool.get_contents()

display(contents)
# Out:
#   network           dims tag                   time_min  \
# 0          time,distance     2022-04-21 05:56:34.998177
# 1          time,distance     2022-04-21 05:56:36.998177
# 2          time,distance     2022-04-21 05:56:37.998177
#
#                     time_max    data_type data_category instrument_id  \
# 0 2022-04-21 05:56:36.997927  strain_rate                    01CE1469
# 1 2022-04-21 05:56:37.997927  strain_rate                    01CE1469
# 2 2022-04-21 05:56:38.997927  strain_rate                    01CE1469
#
#         path file_format              time_step file_version station  \
# 0  patch3.h5      DASDAE 0 days 00:00:00.000250            1
# 1  patch2.h5      DASDAE 0 days 00:00:00.000250            1
# 2  patch1.h5      DASDAE 0 days 00:00:00.000250            1
#
#   experiment_id  _modified
# 0                    False
# 1                    False
# 2                    False

# %% [markdown]
# According to "spool.get_contents()", the 3 patches we prepared have a time span of:
#
# | **path**         | **time_min**                | **time_max**                |
# |------------------|-----------------------------|-----------------------------|
# | `patch3.h5`      | `2022-04-21 05:56:34.998177` | `2022-04-21 05:56:36.997927` |
# | `patch2.h5`      | `2022-04-21 05:56:36.998177` | `2022-04-21 05:56:37.997927` |
# | `patch1.h5`      | `2022-04-21 05:56:37.998177` | `2022-04-21 05:56:38.997927` |
#
# The three files follow one another in time.

# %%
#you can access a Patch in a Spool just as you would access an object in a list
spool[2].viz.waterfall(show=True,scale=(-2,2))#the third patch contains a seismic event
# Out:
# <Axes: xlabel='distance', ylabel='time'>

# %% [markdown]
# ## Map
# Use the map method apply a function to all patches in a spool

# %%
def sta_lta(patch, sta_window, lta_window):
    """
    Compute the non-recursive STA/LTA ratio for a DASCore Patch object.

    Parameters:
    -----------
    patch : dascore.core.Patch
        The DASCore Patch object containing the time-series data.
    sta_window : int
        Window size (in samples) for the Short-Term Average.
    lta_window : int
        Window size (in samples) for the Long-Term Average.

    Returns:
    --------
    sta_lta_patch : dascore.core.Patch
        A new Patch object containing the STA/LTA ratio.
    """
    # Extract data
    data = patch.data

    # Compute the squared values
    patch_square = patch.new(data=np.square(data), attrs=patch.attrs)

    # Compute Short-Term Average (STA) and Long-Term Average (LTA) using DASCore rolling function
    sta = patch_square.rolling(time=sta_window,samples =True).mean().data
    lta = patch_square.rolling(time=lta_window,samples =True).mean().data

    # Avoid division by zero in LTA
    with np.errstate(divide='ignore', invalid='ignore'):
        sta_lta_ratio = np.where(lta > 0, sta / lta, 0)

    # Create a new Patch with the STA/LTA ratio
    sta_lta_patch = patch.new(data=sta_lta_ratio, attrs=patch.attrs)

    return sta_lta_patch.update_attrs(data_type = 'sta_lta') #update data_type

# %% [markdown]
# Apply sta_lta function to all patches in the spool. The sta_window and lta_window will be passed to sta_lta function as keyword arguments.
# The function you want to map must be a callable function which takes a patch as its first argument.

# %%
#sta_window: 0.1s, lta_window: 0.5s
map_stalta = spool.map(sta_lta,sta_window=400,lta_window=2000, progress=False)
#The ‘progress’ argument controls whether to display the progress bar

# %%
map_stalta[2].viz.waterfall(show=True, scale=0.8)
# Out:
# <Axes: xlabel='distance', ylabel='time'>

# %% [markdown]
# The STA/LTA trace has an inherent delay equal to the LTA window length, so the first 0.5s has no effective output.
# ![Screenshot 2025-04-09 at 11.17.13 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## Chunk
# Chunk the data in the spool along specified dimension

# %%
subspool=spool.chunk(time=2, overlap=1)

# %%
subspool.get_contents()
# Out:
#                     time_min                   time_max  \
# 0 2022-04-21 05:56:34.998177 2022-04-21 05:56:36.997927
# 1 2022-04-21 05:56:35.998177 2022-04-21 05:56:37.997927
# 2 2022-04-21 05:56:36.998177 2022-04-21 05:56:38.997927
#
#                time_step           dims network data_category instrument_id  \
# 0 0 days 00:00:00.000250  time,distance                            01CE1469
# 1 0 days 00:00:00.000250  time,distance                            01CE1469
# 2 0 days 00:00:00.000250  time,distance                            01CE1469
#
#   experiment_id tag station    data_type _group
# 0                            strain_rate  0_0_0
# 1                            strain_rate  0_0_0
# 2                            strain_rate  0_0_0

# %% [markdown]
# Map the stalta function to chunked spool

# %%
map_stalta = spool.chunk(time=2, overlap=1).map(sta_lta,sta_window=400,lta_window=2000, progress=False)

# %% [markdown]
# By using overlapping signal segments, each segment produces a valid STA/LTA trace without losing the initial portion due to windowing effects.

# %%
map_stalta[2].viz.waterfall(show=True, scale=1.0)
# Out:
# <Axes: xlabel='distance', ylabel='time'>

# %% [markdown]
# ## Selecting
# The cell below will create a new spool. We only care about the das2 and das3 network pieces of the directory's contents, so we'll look at the original contents, select, and look at the reduced contents in the subspool after selecting.

# %%
in_memory_spool = dc.get_example_spool("diverse_das")

das_folder_path = dc.examples.spool_to_directory(in_memory_spool)
spool = dc.spool(das_folder_path)

# %%
contents = spool.get_contents()

display(contents)
# Out:
#                 time_step           dims data_category network instrument_id  \
# 0  0 days 00:00:00.004000  distance,time
# 1  0 days 00:00:00.004000  distance,time                  das2
# 2  0 days 00:00:00.004000  distance,time
# 3  0 days 00:00:00.004000  distance,time
# 4  0 days 00:00:00.004000  distance,time
# 5  0 days 00:00:00.004000  distance,time
# 6  0 days 00:00:00.004000  distance,time
# 7  0 days 00:00:00.004000  distance,time
# 8  0 days 00:00:00.004000  distance,time
# 9  0 days 00:00:00.004000  distance,time                  das2
# 10 0 days 00:00:00.004000  distance,time
# 11 0 days 00:00:00.004000  distance,time
# 12 0 days 00:00:00.004000  distance,time
# 13 0 days 00:00:00.004000  distance,time                  das2
# 14 0 days 00:00:00.004000  distance,time
# 15 0 days 00:00:00.004000  distance,time
# 16 0 days 00:00:00.004000  distance,time
# 17 0 days 00:00:00.004000  distance,time
#
#                   time_max file_version experiment_id file_format       tag  \
# 0  1989-05-04 00:00:07.996            1                    DASDAE    random
# 1  2020-01-03 00:00:07.996            1                    DASDAE    random
# 2  2020-01-03 00:00:07.996            1                    DASDAE    random
# 3  2020-01-03 00:00:07.996            1                    DASDAE    random
# 4  2020-01-03 00:00:07.996            1                    DASDAE    random
# 5  2020-01-03 00:00:07.996            1                    DASDAE  some_tag
# 6  2020-01-03 00:00:07.996            1                    DASDAE    random
# 7  2020-01-03 00:00:15.986            1                    DASDAE    random
# 8  2020-01-03 00:00:15.996            1                    DASDAE    random
# 9  2020-01-03 00:00:15.996            1                    DASDAE    random
# 10 2020-01-03 00:00:16.000            1                    DASDAE    random
# 11 2020-01-03 00:00:16.996            1                    DASDAE    random
# 12 2020-01-03 00:00:23.976            1                    DASDAE    random
# 13 2020-01-03 00:00:23.996            1                    DASDAE    random
# 14 2020-01-03 00:00:23.996            1                    DASDAE    random
# 15 2020-01-03 00:00:24.004            1                    DASDAE    random
# 16 2020-01-03 00:00:25.996            1                    DASDAE    random
# 17 2030-01-01 00:00:07.996            1                    DASDAE    random
#
#      station                                               path  \
# 0     wayout  DAS_____wayout__random__1989_05_04__1989_05_04...
# 1             DAS___das2____random__2020_01_03__2020_01_03T0...
# 2     smallg  DAS_____smallg__random__2020_01_03__2020_01_03...
# 3             DAS_______random__2020_01_03__2020_01_03T00_00...
# 4   big_gaps  DAS_____big_gaps__random__2020_01_03__2020_01_...
# 5             DAS_______some_tag__2020_01_03__2020_01_03T00_...
# 6   overlaps  DAS_____overlaps__random__2020_01_03__2020_01_...
# 7   overlaps  DAS_____overlaps__random__2020_01_03T00_00_07_...
# 8             DAS_______random__2020_01_03T00_00_08__2020_01...
# 9             DAS___das2____random__2020_01_03T00_00_08__202...
# 10    smallg  DAS_____smallg__random__2020_01_03T00_00_08__2...
# 11  big_gaps  DAS_____big_gaps__random__2020_01_03T00_00_09_...
# 12  overlaps  DAS_____overlaps__random__2020_01_03T00_00_15_...
# 13            DAS___das2____random__2020_01_03T00_00_16__202...
# 14            DAS_______random__2020_01_03T00_00_16__2020_01...
# 15    smallg  DAS_____smallg__random__2020_01_03T00_00_16__2...
# 16  big_gaps  DAS_____big_gaps__random__2020_01_03T00_00_18_...
# 17    wayout  DAS_____wayout__random__2030_01_01__2030_01_01...
#
#                   time_min data_type  _modified
# 0  1989-05-04 00:00:00.000                False
# 1  2020-01-03 00:00:00.000                False
# 2  2020-01-03 00:00:00.000                False
# 3  2020-01-03 00:00:00.000                False
# 4  2020-01-03 00:00:00.000                False
# 5  2020-01-03 00:00:00.000                False
# 6  2020-01-03 00:00:00.000                False
# 7  2020-01-03 00:00:07.990                False
# 8  2020-01-03 00:00:08.000                False
# 9  2020-01-03 00:00:08.000                False
# 10 2020-01-03 00:00:08.004                False
# 11 2020-01-03 00:00:09.000                False
# 12 2020-01-03 00:00:15.980                False
# 13 2020-01-03 00:00:16.000                False
# 14 2020-01-03 00:00:16.000                False
# 15 2020-01-03 00:00:16.008                False
# 16 2020-01-03 00:00:18.000                False
# 17 2030-01-01 00:00:00.000                False

# %% [markdown]
# Use select method to select patches with network code 'das2' and 'das3'

# %%
subspool1 = spool.select(network={'das2', 'das3'})#network is the name of the parameter you hope to select

# %%
contents = subspool.get_contents()

display(contents)
# Out:
#                     time_min                   time_max  \
# 0 2022-04-21 05:56:34.998177 2022-04-21 05:56:36.997927
# 1 2022-04-21 05:56:35.998177 2022-04-21 05:56:37.997927
# 2 2022-04-21 05:56:36.998177 2022-04-21 05:56:38.997927
#
#                time_step           dims network data_category instrument_id  \
# 0 0 days 00:00:00.000250  time,distance                            01CE1469
# 1 0 days 00:00:00.000250  time,distance                            01CE1469
# 2 0 days 00:00:00.000250  time,distance                            01CE1469
#
#   experiment_id tag station    data_type _group
# 0                            strain_rate  0_0_0
# 1                            strain_rate  0_0_0
# 2                            strain_rate  0_0_0

# %% [markdown]
# Select on coordinates

# %%
#similar with the select method in Patch part
subspool2 = subspool1.select(time=('2020-01-03T00:00:09', None))#to select based on a dimensional range, you should pass the range as a tuple

# %%
contents = subspool2.get_contents()

display(contents)
# Out:
#                 time_step           dims data_category network instrument_id  \
# 9  0 days 00:00:00.004000  distance,time                  das2
# 13 0 days 00:00:00.004000  distance,time                  das2
#
#                   time_max file_version experiment_id file_format     tag  \
# 9  2020-01-03 00:00:15.996            1                    DASDAE  random
# 13 2020-01-03 00:00:23.996            1                    DASDAE  random
#
#    station                                               path  \
# 9           DAS___das2____random__2020_01_03T00_00_08__202...
# 13          DAS___das2____random__2020_01_03T00_00_16__202...
#
#               time_min data_type  _modified
# 9  2020-01-03 00:00:09                 True
# 13 2020-01-03 00:00:16                False

# %% [markdown]
# Use "*" to select tags that end with “tag”.

# %%
subspool3 = spool.select(tag="*tag")

# %%
contents = subspool3.get_contents()

display(contents)
# Out:
#                time_step           dims data_category network instrument_id  \
# 5 0 days 00:00:00.004000  distance,time
#
#                  time_max file_version experiment_id file_format       tag  \
# 5 2020-01-03 00:00:07.996            1                    DASDAE  some_tag
#
#   station                                               path   time_min  \
# 5          DAS_______some_tag__2020_01_03__2020_01_03T00_... 2020-01-03
#
#   data_type  _modified
# 5                False
