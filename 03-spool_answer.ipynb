# %% [markdown]
# # Practice Problems with Spools
#
# Let's practice some of the skills we've just seen for working with spools.
#
# If you get stuck, please talk to any of the workshop facilitators, or check out spool_answer.ipynb for hints and completed solutions.

# %% [markdown]
# ## Environment Setup
# Run the cells below for your setup.

# %%
# %%capture

# First ensure DASCore is installed. If not, install and restart the kernel.
try:
    import dascore as dc
except ImportError:
    # !pip install dascore
    # !pip install ipympl
    # resetart kernel
    import IPython
    IPython.Application.instance().kernel.do_shutdown(True) #automatically restarts kernel


import numpy as np
from rich import print
# Out:
# Collecting dascore
#   Downloading dascore-0.1.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from dascore) (3.13.0)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.11/dist-packages (from dascore) (3.10.0)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from dascore) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from dascore) (24.2)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.11/dist-packages (from dascore) (2.2.2)
# Requirement already satisfied: pooch>=1.2 in /usr/local/lib/python3.11/dist-packages (from dascore) (1.8.2)
# Requirement already satisfied: pydantic>2.1 in /usr/local/lib/python3.11/dist-packages (from dascore) (2.11.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from dascore) (13.9.4)
# Requirement already satisfied: scipy>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from dascore) (1.14.1)
# Requirement already satisfied: tables>=3.7 in /usr/local/lib/python3.11/dist-packages (from dascore) (3.10.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from dascore) (4.13.1)
# Collecting pint (from dascore)
#   Downloading Pint-0.24.4-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->dascore) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->dascore) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->dascore) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->dascore) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->dascore) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->dascore) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.5->dascore) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dascore) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0->dascore) (2025.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.2->dascore) (4.3.7)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.2->dascore) (2.32.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>2.1->dascore) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>2.1->dascore) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>2.1->dascore) (0.4.0)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.11/dist-packages (from tables>=3.7->dascore) (2.10.2)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from tables>=3.7->dascore) (9.0.0)
# Requirement already satisfied: blosc2>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from tables>=3.7->dascore) (3.2.1)
# Collecting flexcache>=0.3 (from pint->dascore)
#   Downloading flexcache-0.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting flexparser>=0.4 (from pint->dascore)
#   Downloading flexparser-0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->dascore) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->dascore) (2.18.0)
# Requirement already satisfied: ndindex in /usr/local/lib/python3.11/dist-packages (from blosc2>=2.3.0->tables>=3.7->dascore) (1.9.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from blosc2>=2.3.0->tables>=3.7->dascore) (1.1.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->dascore) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->dascore) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.2->dascore) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.2->dascore) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.2->dascore) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.2->dascore) (2025.1.31)
# Downloading dascore-0.1.6-py3-none-any.whl (273 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.2/273.2 kB 4.4 MB/s eta 0:00:00
# Downloading Pint-0.24.4-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 12.6 MB/s eta 0:00:00
# Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Downloading flexparser-0.4-py3-none-any.whl (27 kB)
# Installing collected packages: flexparser, flexcache, pint, dascore
# Successfully installed dascore-0.1.6 flexcache-0.3 flexparser-0.4 pint-0.24.4

# %%
import numpy as np

import dascore as dc
from dascore.utils.time import to_timedelta64

# %%
dc.__version__
# Out:
# '0.1.6'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Practice: Create a spool
#
# Create a spool that only contains the file "Spool_example_data/patch3.h5".
#
# You'll need to change the das_folder_path to the path for your data (either locally or on Google Drive). If you're pulling data from Google Drive, you'll need to make a shortcut to the directory you're referring to.
# If your shortcut of "Example_data" is in "MyDrive", the cell below shows the path to the folder "Spool_example_data".

# %%
das_folder_path = "drive/MyDrive/Example_data/Spool_example_data"

# %%
#Answer here
spool = dc.spool("drive/MyDrive/Example_data/Spool_example_data/patch3.h5")

# %%
print(spool)
# Out:
# DASCore FileSpool 🧵 (1 Patch) Path: drive/MyDrive/Example_data/Spool_example_data/patch3.h5

# %%
contents = spool.get_contents()

display(contents)
# Out:
#      data_type data_category data_units instrument_id acquisition_id tag  \
# 0  strain_rate                     None      01CE1469
#
#   station network           dims _cdims_distance  ...  time_dtype  \
# 0                  time,distance        distance  ...  datetime64
#
#                     time_min                   time_max  \
# 0 2022-04-21 05:56:34.998177 2022-04-21 05:56:36.997927
#
#                time_step time_units distance_dtype distance_min distance_max  \
# 0 0 days 00:00:00.000250          s          int64           95         1050
#
#   distance_step distance_units
# 0             1           None
#
# [1 rows x 24 columns]

# %% [markdown]
# ## Practice: Chunk a spool
#
# Chunk the spool to have 0.5 second patches with 0.25 second overlaps. How can you visualize the results or print information about the results to know whether this was successful?

# %%
#Answer here
subspool = spool.chunk(time=0.5, overlap=0.25)

# %% [markdown]
# ## Practice: Map method
#
# Use the map method to apply a patch taper method to all patches in the spool using "hamming" window type. Try to visualize the results as you change the taper parameter.

# %%
#Answer here
def taper(patch,time,window_type):
    return patch.taper(time=time,window_type=window_type)

# %%
subspool_taper = subspool.map(taper,time=0.1,window_type="hamming")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
subspool_taper[1].viz.waterfall()
# Out:
# <Axes: xlabel='distance', ylabel='time'>

# %%
subspool_taper_30 = subspool.map(taper,time=0.3,window_type="hamming")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
subspool_taper_30[1].viz.waterfall()
# Out:
# <Axes: xlabel='distance', ylabel='time'>

# %% [markdown]
# ## Practice: Select method
#
# The cell below will create a new spool. Create a sub-spool of the new spool by selecting all patches with a station code that ends with an 's'.

# %%
in_memory_spool = dc.get_example_spool("diverse_das")

das_folder_path = dc.examples.spool_to_directory(in_memory_spool)
spool = dc.spool(das_folder_path)

# %%
contents = spool.get_contents()

display(contents)
# Out:
#      station              time_step network instrument_id file_format  \
# 0     wayout 0 days 00:00:00.004000                            DASDAE
# 1            0 days 00:00:00.004000                            DASDAE
# 2   overlaps 0 days 00:00:00.004000                            DASDAE
# 3     smallg 0 days 00:00:00.004000                            DASDAE
# 4   big_gaps 0 days 00:00:00.004000                            DASDAE
# 5            0 days 00:00:00.004000    das2                    DASDAE
# 6            0 days 00:00:00.004000                            DASDAE
# 7   overlaps 0 days 00:00:00.004000                            DASDAE
# 8            0 days 00:00:00.004000                            DASDAE
# 9            0 days 00:00:00.004000    das2                    DASDAE
# 10    smallg 0 days 00:00:00.004000                            DASDAE
# 11  big_gaps 0 days 00:00:00.004000                            DASDAE
# 12  overlaps 0 days 00:00:00.004000                            DASDAE
# 13           0 days 00:00:00.004000                            DASDAE
# 14           0 days 00:00:00.004000    das2                    DASDAE
# 15    smallg 0 days 00:00:00.004000                            DASDAE
# 16  big_gaps 0 days 00:00:00.004000                            DASDAE
# 17    wayout 0 days 00:00:00.004000                            DASDAE
#
#                   time_min data_category  \
# 0  1989-05-04 00:00:00.000
# 1  2020-01-03 00:00:00.000
# 2  2020-01-03 00:00:00.000
# 3  2020-01-03 00:00:00.000
# 4  2020-01-03 00:00:00.000
# 5  2020-01-03 00:00:00.000
# 6  2020-01-03 00:00:00.000
# 7  2020-01-03 00:00:07.990
# 8  2020-01-03 00:00:08.000
# 9  2020-01-03 00:00:08.000
# 10 2020-01-03 00:00:08.004
# 11 2020-01-03 00:00:09.000
# 12 2020-01-03 00:00:15.980
# 13 2020-01-03 00:00:16.000
# 14 2020-01-03 00:00:16.000
# 15 2020-01-03 00:00:16.008
# 16 2020-01-03 00:00:18.000
# 17 2030-01-01 00:00:00.000
#
#                                                  path experiment_id  \
# 0   DAS_____wayout__random__1989_05_04__1989_05_04...
# 1   DAS_______random__2020_01_03__2020_01_03T00_00...
# 2   DAS_____overlaps__random__2020_01_03__2020_01_...
# 3   DAS_____smallg__random__2020_01_03__2020_01_03...
# 4   DAS_____big_gaps__random__2020_01_03__2020_01_...
# 5   DAS___das2____random__2020_01_03__2020_01_03T0...
# 6   DAS_______some_tag__2020_01_03__2020_01_03T00_...
# 7   DAS_____overlaps__random__2020_01_03T00_00_07_...
# 8   DAS_______random__2020_01_03T00_00_08__2020_01...
# 9   DAS___das2____random__2020_01_03T00_00_08__202...
# 10  DAS_____smallg__random__2020_01_03T00_00_08__2...
# 11  DAS_____big_gaps__random__2020_01_03T00_00_09_...
# 12  DAS_____overlaps__random__2020_01_03T00_00_15_...
# 13  DAS_______random__2020_01_03T00_00_16__2020_01...
# 14  DAS___das2____random__2020_01_03T00_00_16__202...
# 15  DAS_____smallg__random__2020_01_03T00_00_16__2...
# 16  DAS_____big_gaps__random__2020_01_03T00_00_18_...
# 17  DAS_____wayout__random__2030_01_01__2030_01_01...
#
#    file_version           dims       tag data_type                time_max  \
# 0             1  distance,time    random           1989-05-04 00:00:07.996
# 1             1  distance,time    random           2020-01-03 00:00:07.996
# 2             1  distance,time    random           2020-01-03 00:00:07.996
# 3             1  distance,time    random           2020-01-03 00:00:07.996
# 4             1  distance,time    random           2020-01-03 00:00:07.996
# 5             1  distance,time    random           2020-01-03 00:00:07.996
# 6             1  distance,time  some_tag           2020-01-03 00:00:07.996
# 7             1  distance,time    random           2020-01-03 00:00:15.986
# 8             1  distance,time    random           2020-01-03 00:00:15.996
# 9             1  distance,time    random           2020-01-03 00:00:15.996
# 10            1  distance,time    random           2020-01-03 00:00:16.000
# 11            1  distance,time    random           2020-01-03 00:00:16.996
# 12            1  distance,time    random           2020-01-03 00:00:23.976
# 13            1  distance,time    random           2020-01-03 00:00:23.996
# 14            1  distance,time    random           2020-01-03 00:00:23.996
# 15            1  distance,time    random           2020-01-03 00:00:24.004
# 16            1  distance,time    random           2020-01-03 00:00:25.996
# 17            1  distance,time    random           2030-01-01 00:00:07.996
#
#     _modified
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False

# %%
#Answer here
subspool_s = spool.select(station="*s")

# %%
contents = subspool_s.get_contents()

display(contents)
# Out:
#      station              time_step network instrument_id file_format  \
# 2   overlaps 0 days 00:00:00.004000                            DASDAE
# 4   big_gaps 0 days 00:00:00.004000                            DASDAE
# 7   overlaps 0 days 00:00:00.004000                            DASDAE
# 11  big_gaps 0 days 00:00:00.004000                            DASDAE
# 12  overlaps 0 days 00:00:00.004000                            DASDAE
# 16  big_gaps 0 days 00:00:00.004000                            DASDAE
#
#                   time_min data_category  \
# 2  2020-01-03 00:00:00.000
# 4  2020-01-03 00:00:00.000
# 7  2020-01-03 00:00:07.990
# 11 2020-01-03 00:00:09.000
# 12 2020-01-03 00:00:15.980
# 16 2020-01-03 00:00:18.000
#
#                                                  path experiment_id  \
# 2   DAS_____overlaps__random__2020_01_03__2020_01_...
# 4   DAS_____big_gaps__random__2020_01_03__2020_01_...
# 7   DAS_____overlaps__random__2020_01_03T00_00_07_...
# 11  DAS_____big_gaps__random__2020_01_03T00_00_09_...
# 12  DAS_____overlaps__random__2020_01_03T00_00_15_...
# 16  DAS_____big_gaps__random__2020_01_03T00_00_18_...
#
#    file_version           dims     tag data_type                time_max  \
# 2             1  distance,time  random           2020-01-03 00:00:07.996
# 4             1  distance,time  random           2020-01-03 00:00:07.996
# 7             1  distance,time  random           2020-01-03 00:00:15.986
# 11            1  distance,time  random           2020-01-03 00:00:16.996
# 12            1  distance,time  random           2020-01-03 00:00:23.976
# 16            1  distance,time  random           2020-01-03 00:00:25.996
#
#     _modified
# 2       False
# 4       False
# 7       False
# 11      False
# 12      False
# 16      False
